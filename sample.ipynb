# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/chang/deepface
# !pip install -e .
from deepface import DeepFace
# %cd /content/drive/MyDrive/chang
from AutoTagger import AutoTagger

# %%
autotagger = AutoTagger(DeepFace, "/content/drive/MyDrive/chang/test_dbv2", "/content/drive/MyDrive/chang/jsons", '/content/drive/MyDrive/chang/db/people.db', model_name='resnet34_finetune')
results = autotagger.tag(target_path = "/content/drive/MyDrive/chang/ttt.jpeg", similarity = "euclidean_l2", k=8)
results
# Out:
# <PIL.Image.Image image mode=RGB size=540x813 at 0x7F8B54204FD0>
#                                             identity  source_x  source_y  \
# 0  /content/drive/MyDrive/chang/test_dbv2/uid=354...       321        64
# 0  /content/drive/MyDrive/chang/test_dbv2/uid=504...       158        84
#
#    source_w  source_h  resnet34_finetune_euclidean_l2  \
# 0       107       107                        1.082397
# 0       108       108                        1.018309
#
#                               target_img matched_uid matched_name
# 0  /content/drive/MyDrive/chang/ttt.jpeg         354        세정
# 0  /content/drive/MyDrive/chang/ttt.jpeg         504     정채연

# %%
results = autotagger.tag(target_path = "/content/drive/MyDrive/chang/sampleimg.jpeg", similarity = "euclidean_l2", k=8)
results
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8B4C07E320>
#                                             identity  source_x  source_y  \
# 0  /content/drive/MyDrive/chang/test_dbv2/uid=354...        53        76
# 0  /content/drive/MyDrive/chang/test_dbv2/uid=504...       407        83
#
#    source_w  source_h  resnet34_finetune_euclidean_l2  \
# 0       184       184                        1.103794
# 0       136       136                        1.043176
#
#                                     target_img matched_uid matched_name
# 0  /content/drive/MyDrive/chang/sampleimg.jpeg         354        세정
# 0  /content/drive/MyDrive/chang/sampleimg.jpeg         504     정채연
