# %%
# !pip install deepface
from deepface import DeepFace
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/chang
#from AutoTagger import AutoTagger

# %%
autotagger = AutoTagger(DeepFace, "/content/drive/MyDrive/chang/test_dbv2", "/content/drive/MyDrive/chang/jsons", '/content/drive/MyDrive/chang/db/people.db')

# %%
results = autotagger.tag(target_path = "/content/drive/MyDrive/chang/train_dbv2/uid=609_전소연12.jpg", similarity = "euclidean_l2")
results
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:28<00:00, 20.5MB/s]
# <PIL.Image.Image image mode=RGB size=197x256 at 0x7FD2AA4144C0>
#                                                         identity  source_x  \
# 0  /content/drive/MyDrive/chang/test_db_v2/uid=609_전소연6.jpg        40
#
#    source_y  source_w  source_h  VGG-Face_euclidean_l2  \
# 0        46       107       107               0.537562
#
#                                                   target_img matched_uid  \
# 0  /content/drive/MyDrive/chang/train_dbv2/uid=609_전소연12.jpg         609
#
#   matched_name
# 0     전소연

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

img_test = img.imread('/content/drive/MyDrive/chang/test_dbv2/uid=609_전소연6.jpg')
plt.imshow(img_test)
plt.show()

# %%
autotagger.print_people()
# Out:
# People in the database:
# ...

# %%
autotagger.check_person_exists('아이오아이_김세정')
# Out:
# 아이오아이_김세정 is already in the database.

# %%
aa = autotagger.insert_person('홍길동')

# %%
metrics, result_pd = autotagger.calc_metrics("/content/drive/MyDrive/chang/train_dbv2")

# %%
metrics
# Out:
# {'precision': 0.40773809523809523}

# %%
metrics, result_pd = autotagger.calc_metrics("/content/drive/MyDrive/chang/train_dbv2", similarity="euclidean_l2")

# %%
metrics
# Out:
# {'precision': 0.4089330024813896}
