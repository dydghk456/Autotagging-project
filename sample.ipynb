# %%
# !pip install deepface
from deepface import DeepFace
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/chang
from AutoTagger import AutoTagger

# %%
autotagger = AutoTagger(DeepFace, "/content/drive/MyDrive/chang/test_db", "/content/drive/MyDrive/chang/jsons", '/content/drive/MyDrive/chang/db/people.db')

# %%
results = autotagger.tag(target_path = "/content/drive/MyDrive/chang/train_db/uid=163_아이오아이_김세정7.jpg")
results
# Out:
# WARNING: Representations for images in /content/drive/MyDrive/chang/test_db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  1440  representations found in  representations_vgg_face.pkl
# find function lasts  10.376968383789062  seconds
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F3C1E4BCF40>
#                                                                 identity  \
# 0  /content/drive/MyDrive/chang/test_db/uid=163_아이오아이_김세정4.jpg
#
#    source_x  source_y  source_w  source_h  VGG-Face_cosine  \
# 0        46        44        82        82         0.219233
#
#                                                      target_img matched_uid  \
# 0  /content/drive/MyDrive/chang/train_db/uid=163_아이오아이_김세정7.jpg         163
#
#   matched_name
# 0     김세정

# %%
autotagger.print_people()

# %%
autotagger.check_person_exists('')

# %%
aa = autotagger.insert_person('홍길동')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

img_test = img.imread('/content/drive/MyDrive/chang/test_db/uid=163_아이오아이_김세정4.jpg')
plt.imshow(img_test)
plt.show()

# %%
metrics, result_pd = autotagger.calc_metrics("/content/drive/MyDrive/chang/train_db")

# %%
metrics[1]
